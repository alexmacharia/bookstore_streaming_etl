-- %%
%fs ls 's3://bookstore-storage-001/'

-- %%
DROP CATALOG IF EXISTS bookstore_dev CASCADE;

CREATE CATALOG IF NOT EXISTS bookstore_dev
MANAGED LOCATION 's3://bookstore-storage-001/bookstore_dev';

-- %%
SHOW CATALOGS;

-- %%
SELECT current_catalog();

-- %%
USE CATALOG bookstore_dev;
