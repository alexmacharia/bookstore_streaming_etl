# %%
# %sql
CREATE CATALOG IF NOT EXISTS test
MANAGED LOCATION 's3://databricks-ext-storage-01/test_catalog';

# %%
# %sql
USE CATALOG test;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 's3://databricks-ext-storage-01/test_catalog/landing';

CREATE SCHEMA IF NOT EXISTS bookstore_db
MANAGED LOCATION 's3://databricks-ext-storage-01/test_catalog/bookstore_db';

# %%
# %sql
USE SCHEMA landing;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS raw_data
LOCATION 's3://databricks-ext-storage-01/test_catalog/landing/raw_data';

# %%
# %fs ls '/Volumes/test/landing/raw_data'
